# %% [markdown]
# ## Alura: Lógica de Programação

# %% [markdown]
# # Variáveis

# %% [markdown]
# Alocando uma String

# %%
nome = 'Lucas'

# %% [markdown]
# Alocando um Inteiro

# %%
idade = 24

# %% [markdown]
# Exibindo as informações das variáveis

# %%
print(f'Meu nome é {nome} e tenho {idade} anos')
# Out:
# Meu nome é Lucas e tenho 24 anos

# %% [markdown]
# # Criando uma função

# %%
def saudacao():
  nome = input('Qual o seu nome? ')
  print(f'Olá {nome}')

# %%
saudacao()
# Out:
# Qual o seu nome? dsadasd
# Olá dsadasd

# %% [markdown]
# # Parâmetros

# %%
nome = 'Aurora'

# %%
def saudacao_com_parametro(nome_da_pessoa):
  print(f'Ola {nome_da_pessoa}')

# %%
saudacao_com_parametro(nome)
# Out:
# Ola Aurora

# %% [markdown]
# # Condicional

# %%
idade = 20
def verifica_se_pode_dirigir(idade):
  if idade >= 18:
    print(f'A idade é {idade} anos. Tem permissão para dirigir!')
  else:
    print(f'A idade é {idade} anos. Não tem permissão para dirigir!')

# %%
verifica_se_pode_dirigir(idade)
# Out:
# A idade é 20 anos. Tem permissão para dirigir!

# %% [markdown]
# # Convertendo tipo para inteiro

# %%
def verifica_se_pode_dirigir_sem_parametros():
  idade = int(input('Qual sua idade? '))
  if idade >= 18:
    print('Tem permissão para dirigir!')
  else:
    print('Não tem permissão para dirigir!')

# %%
verifica_se_pode_dirigir_sem_parametros()
# Out:
# Qual sua idade? 20
# Tem permissão para dirigir!

# %% [markdown]
# # Listas

# %%
idade = 22
idade
# Out:
# 22

# %%
type(idade)
# Out:
# int

# %%
idades = [10, 15, 20, 25, 30]
#         0   1   2   3   4
#        -5  -4  -3  -2  -1
type(idades)
# Out:
# list

# %%
idades[2]
# Out:
# 20

# %%
idades[0:3]
# Out:
# [10, 15, 20]

# %%
idades[0:]
# Out:
# [10, 15, 20, 25, 30]

# %%
idades[-1]
# Out:
# 30

# %%
idades[0]
# Out:
# 10

# %% [markdown]
# # Laços e Loops

# %%
idades
# Out:
# [10, 15, 20, 25, 30]

# %%
# FOR FORA DA FUNÇÃO

def verifica_se_pode_dirigir(idade):
  if idade >= 18:
    print(f'A idade é {idade} anos. TEM permissão para dirigir!')
  else:
    print(f'A idade é {idade} anos. NÃO TEM permissão para dirigir!')

# %%
for idade in idades:
  verifica_se_pode_dirigir(idade)
# Out:
# A idade é 10 anos. NÃO TEM permissão para dirigir!
# A idade é 15 anos. NÃO TEM permissão para dirigir!
# A idade é 20 anos. TEM permissão para dirigir!
# A idade é 25 anos. TEM permissão para dirigir!
# A idade é 30 anos. TEM permissão para dirigir!

# %%
# FOR DENTRO DA FUNÇÃO

def verifica_se_pode_dirigir(idades):
  for idade in idades:
    if idade >= 18:
        print(f'A idade é {idade} anos. TEM permissão para dirigir!')
    else:
        print(f'A idade é {idade} anos. NÃO TEM permissão para dirigir!')

# %%
verifica_se_pode_dirigir(idades)
# Out:
# A idade é 10 anos. NÃO TEM permissão para dirigir!
# A idade é 15 anos. NÃO TEM permissão para dirigir!
# A idade é 20 anos. TEM permissão para dirigir!
# A idade é 25 anos. TEM permissão para dirigir!
# A idade é 30 anos. TEM permissão para dirigir!

# %% [markdown]
# # Boleano

# %%
idade = 18
idade >= 18
# Out:
# True

# %%
idade = 15
idade >= 18
# Out:
# False

# %%
permissoes = []
idades = [20, 14, 40]

def verifica_se_pode_dirigir(idades, permissoes):
  for idade in idades:
    if idade >= 18:
      permissoes.append(True)
    else:
      permissoes.append(False)

verifica_se_pode_dirigir(idades, permissoes)

# %%
permissoes
# Out:
# [True, False, True]

# %%
for permissao in permissoes:
  if permissao == True:
    print('TEM permissão para dirigir!')
  else:
    print('NÃO TEM permissão para dirigir!')
# Out:
# TEM permissão para dirigir!
# NÃO TEM permissão para dirigir!
# TEM permissão para dirigir!

# %% [markdown]
# # Tipos em uma lista

# %%
lista = ['Lucas', 24, True, 3.14]

for elemento in lista:
  print(f'O elemento {elemento} é do tipo: {type(elemento)}')
# Out:
# O elemento Lucas é do tipo: <class 'str'>
# O elemento 24 é do tipo: <class 'int'>
# O elemento True é do tipo: <class 'bool'>
# O elemento 3.14 é do tipo: <class 'float'>

# %% [markdown]
# # Import

# %%
from random import randrange, seed

# %%
seed(11)

# %%
randrange(0, 11)
# Out:
# 7

# %%
notas_matematica = []

for notas in range(8):
  notas_matematica.append(randrange(0, 11))

notas_matematica
# Out:
# [8, 7, 7, 8, 9, 3, 2, 8]

# %%
len(notas_matematica)
# Out:
# 8

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = list(range(1, 9))
y = notas_matematica
plt.plot(x, y, marker='o', linewidth=2.0)
plt.grid(linewidth=1.0)
plt.title('Notas de Matemática')
plt.xlabel('Provas')
plt.ylabel('Notas')
plt.show()

# %%
# Out:
# [8, 7, 7, 8, 9, 3, 2, 8]
